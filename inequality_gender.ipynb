# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn

############################ loading data ############################
test = pd.read_csv("test.csv")

# %%
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872749 entries, 0 to 872748
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   travel_purpose       872749 non-null  object
#  1   starting_point       872749 non-null  object
#  2   ending_point         872749 non-null  object
#  3   transportation_mode  872749 non-null  object
#  4   start_time           872749 non-null  object
#  5   end_time             872749 non-null  object
#  6   travel_time          872749 non-null  int64
#  7   waiting_time         872749 non-null  int64
#  8   social_class         872749 non-null  object
#  9   local_size           872749 non-null  object
#  10  sex                  872749 non-null  object
#  11  age                  872749 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 79.9+ MB

# %% [markdown]
# ### male vs female ##

# %%
female_test = test[test['sex'] == 'Female']
male_test = test[test['sex'] == 'Male']

# %%
female_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 434412 entries, 0 to 872748
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   travel_purpose       434412 non-null  object
#  1   starting_point       434412 non-null  object
#  2   ending_point         434412 non-null  object
#  3   transportation_mode  434412 non-null  object
#  4   start_time           434412 non-null  object
#  5   end_time             434412 non-null  object
#  6   travel_time          434412 non-null  int64
#  7   waiting_time         434412 non-null  int64
#  8   social_class         434412 non-null  object
#  9   local_size           434412 non-null  object
#  10  sex                  434412 non-null  object
#  11  age                  434412 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 43.1+ MB

# %%
def undersample(df, target):
    # 获取每个类别的索引
    class_indices = [df[df[target] == label].index for label in df[target].unique()]
    undersampled_size = min(len(indices) for indices in class_indices)
    
    # 欠采样
    undersampled_indices = [indices[:undersampled_size] for indices in class_indices]
    undersampled_indices = np.concatenate(undersampled_indices)
    
    return df.loc[undersampled_indices]

# %%
female_data_undersampled = undersample(female_test, 'travel_purpose')
print("欠采样后的样本数量: ", len(female_data_undersampled))
# Out:
# 欠采样后的样本数量:  30736

# %%
male_data_undersampled = undersample(male_test, 'travel_purpose')
print("欠采样后的样本数量: ", len(male_data_undersampled))
# Out:
# 欠采样后的样本数量:  22424

# %%
female_testing = female_data_undersampled.drop(
    [
    "travel_purpose",
    "sex"
    ],
    axis = 1
)

female_testing_numeric = pd.get_dummies(female_testing)
female_testing_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30736 entries, 0 to 872449
# Data columns (total 67 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   travel_time                                                            30736 non-null  int64
#  1   waiting_time                                                           30736 non-null  int64
#  2   starting_point_Construction Site                                       30736 non-null  bool
#  3   starting_point_Cultural Center or Leisure Area                         30736 non-null  bool
#  4   starting_point_Factory or Workshop                                     30736 non-null  bool
#  5   starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory  30736 non-null  bool
#  6   starting_point_Office                                                  30736 non-null  bool
#  7   starting_point_Other Enclosures                                        30736 non-null  bool
#  8   starting_point_Other Services                                          30736 non-null  bool
#  9   starting_point_Others                                                  30736 non-null  bool
#  10  starting_point_Public Transportation Hub or Station                    30736 non-null  bool
#  11  starting_point_Religious Area                                          30736 non-null  bool
#  12  starting_point_Restaurant, Bar, Cafe                                   30736 non-null  bool
#  13  starting_point_School                                                  30736 non-null  bool
#  14  starting_point_Shop, Market, Store, or Shopping Mall                   30736 non-null  bool
#  15  starting_point_Sports, Gym                                             30736 non-null  bool
#  16  starting_point_Thoroughfare                                            30736 non-null  bool
#  17  starting_point_Your Home                                               30736 non-null  bool
#  18  ending_point_Construction Site                                         30736 non-null  bool
#  19  ending_point_Cultural Center or Leisure Area                           30736 non-null  bool
#  20  ending_point_Factory or Workshop                                       30736 non-null  bool
#  21  ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory    30736 non-null  bool
#  22  ending_point_Office                                                    30736 non-null  bool
#  23  ending_point_Other Enclosures                                          30736 non-null  bool
#  24  ending_point_Other Services                                            30736 non-null  bool
#  25  ending_point_Others                                                    30736 non-null  bool
#  26  ending_point_Public Transportation Hub or Station                      30736 non-null  bool
#  27  ending_point_Religious Area                                            30736 non-null  bool
#  28  ending_point_Restaurant, Bar, Cafe                                     30736 non-null  bool
#  29  ending_point_School                                                    30736 non-null  bool
#  30  ending_point_Shop, Market, Store, or Shopping Mall                     30736 non-null  bool
#  31  ending_point_Sports, Gym                                               30736 non-null  bool
#  32  ending_point_Thoroughfare                                              30736 non-null  bool
#  33  ending_point_Your Home                                                 30736 non-null  bool
#  34  transportation_mode_Bus                                                30736 non-null  bool
#  35  transportation_mode_Others                                             30736 non-null  bool
#  36  transportation_mode_Private                                            30736 non-null  bool
#  37  transportation_mode_Rail                                               30736 non-null  bool
#  38  transportation_mode_Taxi                                               30736 non-null  bool
#  39  transportation_mode_Walking                                            30736 non-null  bool
#  40  transportation_mode_cycles                                             30736 non-null  bool
#  41  start_time_Afternoon                                                   30736 non-null  bool
#  42  start_time_Evening                                                     30736 non-null  bool
#  43  start_time_Midnight                                                    30736 non-null  bool
#  44  start_time_Morning                                                     30736 non-null  bool
#  45  start_time_Night                                                       30736 non-null  bool
#  46  start_time_Noon                                                        30736 non-null  bool
#  47  end_time_Afternoon                                                     30736 non-null  bool
#  48  end_time_Evening                                                       30736 non-null  bool
#  49  end_time_Midnight                                                      30736 non-null  bool
#  50  end_time_Morning                                                       30736 non-null  bool
#  51  end_time_Night                                                         30736 non-null  bool
#  52  end_time_Noon                                                          30736 non-null  bool
#  53  social_class_High Class                                                30736 non-null  bool
#  54  social_class_Low Class                                                 30736 non-null  bool
#  55  social_class_Lower-Medium Class                                        30736 non-null  bool
#  56  social_class_Upper-Medium Class                                        30736 non-null  bool
#  57  local_size_From 15000 to 99999 people                                  30736 non-null  bool
#  58  local_size_From 2500 to 14999 people                                   30736 non-null  bool
#  59  local_size_Over 100000 people                                          30736 non-null  bool
#  60  local_size_less than 2500 people                                       30736 non-null  bool
#  61  age_Adult                                                              30736 non-null  bool
#  62  age_Child                                                              30736 non-null  bool
#  63  age_Middle-aged                                                        30736 non-null  bool
#  64  age_Senior                                                             30736 non-null  bool
#  65  age_Teenager                                                           30736 non-null  bool
#  66  age_Young Adult                                                        30736 non-null  bool
# dtypes: bool(65), int64(2)
# memory usage: 2.6 MB

# %%
male_testing = male_data_undersampled.drop(
    [
    "travel_purpose",
    "sex"
    ],
    axis = 1
)

male_testing_numeric = pd.get_dummies(male_testing)
male_testing_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22424 entries, 14 to 872729
# Data columns (total 67 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   travel_time                                                            22424 non-null  int64
#  1   waiting_time                                                           22424 non-null  int64
#  2   starting_point_Construction Site                                       22424 non-null  bool
#  3   starting_point_Cultural Center or Leisure Area                         22424 non-null  bool
#  4   starting_point_Factory or Workshop                                     22424 non-null  bool
#  5   starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory  22424 non-null  bool
#  6   starting_point_Office                                                  22424 non-null  bool
#  7   starting_point_Other Enclosures                                        22424 non-null  bool
#  8   starting_point_Other Services                                          22424 non-null  bool
#  9   starting_point_Others                                                  22424 non-null  bool
#  10  starting_point_Public Transportation Hub or Station                    22424 non-null  bool
#  11  starting_point_Religious Area                                          22424 non-null  bool
#  12  starting_point_Restaurant, Bar, Cafe                                   22424 non-null  bool
#  13  starting_point_School                                                  22424 non-null  bool
#  14  starting_point_Shop, Market, Store, or Shopping Mall                   22424 non-null  bool
#  15  starting_point_Sports, Gym                                             22424 non-null  bool
#  16  starting_point_Thoroughfare                                            22424 non-null  bool
#  17  starting_point_Your Home                                               22424 non-null  bool
#  18  ending_point_Construction Site                                         22424 non-null  bool
#  19  ending_point_Cultural Center or Leisure Area                           22424 non-null  bool
#  20  ending_point_Factory or Workshop                                       22424 non-null  bool
#  21  ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory    22424 non-null  bool
#  22  ending_point_Office                                                    22424 non-null  bool
#  23  ending_point_Other Enclosures                                          22424 non-null  bool
#  24  ending_point_Other Services                                            22424 non-null  bool
#  25  ending_point_Others                                                    22424 non-null  bool
#  26  ending_point_Public Transportation Hub or Station                      22424 non-null  bool
#  27  ending_point_Religious Area                                            22424 non-null  bool
#  28  ending_point_Restaurant, Bar, Cafe                                     22424 non-null  bool
#  29  ending_point_School                                                    22424 non-null  bool
#  30  ending_point_Shop, Market, Store, or Shopping Mall                     22424 non-null  bool
#  31  ending_point_Sports, Gym                                               22424 non-null  bool
#  32  ending_point_Thoroughfare                                              22424 non-null  bool
#  33  ending_point_Your Home                                                 22424 non-null  bool
#  34  transportation_mode_Bus                                                22424 non-null  bool
#  35  transportation_mode_Others                                             22424 non-null  bool
#  36  transportation_mode_Private                                            22424 non-null  bool
#  37  transportation_mode_Rail                                               22424 non-null  bool
#  38  transportation_mode_Taxi                                               22424 non-null  bool
#  39  transportation_mode_Walking                                            22424 non-null  bool
#  40  transportation_mode_cycles                                             22424 non-null  bool
#  41  start_time_Afternoon                                                   22424 non-null  bool
#  42  start_time_Evening                                                     22424 non-null  bool
#  43  start_time_Midnight                                                    22424 non-null  bool
#  44  start_time_Morning                                                     22424 non-null  bool
#  45  start_time_Night                                                       22424 non-null  bool
#  46  start_time_Noon                                                        22424 non-null  bool
#  47  end_time_Afternoon                                                     22424 non-null  bool
#  48  end_time_Evening                                                       22424 non-null  bool
#  49  end_time_Midnight                                                      22424 non-null  bool
#  50  end_time_Morning                                                       22424 non-null  bool
#  51  end_time_Night                                                         22424 non-null  bool
#  52  end_time_Noon                                                          22424 non-null  bool
#  53  social_class_High Class                                                22424 non-null  bool
#  54  social_class_Low Class                                                 22424 non-null  bool
#  55  social_class_Lower-Medium Class                                        22424 non-null  bool
#  56  social_class_Upper-Medium Class                                        22424 non-null  bool
#  57  local_size_From 15000 to 99999 people                                  22424 non-null  bool
#  58  local_size_From 2500 to 14999 people                                   22424 non-null  bool
#  59  local_size_Over 100000 people                                          22424 non-null  bool
#  60  local_size_less than 2500 people                                       22424 non-null  bool
#  61  age_Adult                                                              22424 non-null  bool
#  62  age_Child                                                              22424 non-null  bool
#  63  age_Middle-aged                                                        22424 non-null  bool
#  64  age_Senior                                                             22424 non-null  bool
#  65  age_Teenager                                                           22424 non-null  bool
#  66  age_Young Adult                                                        22424 non-null  bool
# dtypes: bool(65), int64(2)
# memory usage: 1.9 MB

# %%
female_testing_final = female_testing_numeric.drop(
    [
        "starting_point_Construction Site",
        "ending_point_Construction Site",
        "transportation_mode_Bus",
        "start_time_Afternoon",
        "end_time_Afternoon",
        "social_class_High Class",
        "local_size_less than 2500 people",
        "age_Child"
    ],
    axis=1
    )

female_testing_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30736 entries, 0 to 872449
# Data columns (total 59 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   travel_time                                                            30736 non-null  int64
#  1   waiting_time                                                           30736 non-null  int64
#  2   starting_point_Cultural Center or Leisure Area                         30736 non-null  bool
#  3   starting_point_Factory or Workshop                                     30736 non-null  bool
#  4   starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory  30736 non-null  bool
#  5   starting_point_Office                                                  30736 non-null  bool
#  6   starting_point_Other Enclosures                                        30736 non-null  bool
#  7   starting_point_Other Services                                          30736 non-null  bool
#  8   starting_point_Others                                                  30736 non-null  bool
#  9   starting_point_Public Transportation Hub or Station                    30736 non-null  bool
#  10  starting_point_Religious Area                                          30736 non-null  bool
#  11  starting_point_Restaurant, Bar, Cafe                                   30736 non-null  bool
#  12  starting_point_School                                                  30736 non-null  bool
#  13  starting_point_Shop, Market, Store, or Shopping Mall                   30736 non-null  bool
#  14  starting_point_Sports, Gym                                             30736 non-null  bool
#  15  starting_point_Thoroughfare                                            30736 non-null  bool
#  16  starting_point_Your Home                                               30736 non-null  bool
#  17  ending_point_Cultural Center or Leisure Area                           30736 non-null  bool
#  18  ending_point_Factory or Workshop                                       30736 non-null  bool
#  19  ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory    30736 non-null  bool
#  20  ending_point_Office                                                    30736 non-null  bool
#  21  ending_point_Other Enclosures                                          30736 non-null  bool
#  22  ending_point_Other Services                                            30736 non-null  bool
#  23  ending_point_Others                                                    30736 non-null  bool
#  24  ending_point_Public Transportation Hub or Station                      30736 non-null  bool
#  25  ending_point_Religious Area                                            30736 non-null  bool
#  26  ending_point_Restaurant, Bar, Cafe                                     30736 non-null  bool
#  27  ending_point_School                                                    30736 non-null  bool
#  28  ending_point_Shop, Market, Store, or Shopping Mall                     30736 non-null  bool
#  29  ending_point_Sports, Gym                                               30736 non-null  bool
#  30  ending_point_Thoroughfare                                              30736 non-null  bool
#  31  ending_point_Your Home                                                 30736 non-null  bool
#  32  transportation_mode_Others                                             30736 non-null  bool
#  33  transportation_mode_Private                                            30736 non-null  bool
#  34  transportation_mode_Rail                                               30736 non-null  bool
#  35  transportation_mode_Taxi                                               30736 non-null  bool
#  36  transportation_mode_Walking                                            30736 non-null  bool
#  37  transportation_mode_cycles                                             30736 non-null  bool
#  38  start_time_Evening                                                     30736 non-null  bool
#  39  start_time_Midnight                                                    30736 non-null  bool
#  40  start_time_Morning                                                     30736 non-null  bool
#  41  start_time_Night                                                       30736 non-null  bool
#  42  start_time_Noon                                                        30736 non-null  bool
#  43  end_time_Evening                                                       30736 non-null  bool
#  44  end_time_Midnight                                                      30736 non-null  bool
#  45  end_time_Morning                                                       30736 non-null  bool
#  46  end_time_Night                                                         30736 non-null  bool
#  47  end_time_Noon                                                          30736 non-null  bool
#  48  social_class_Low Class                                                 30736 non-null  bool
#  49  social_class_Lower-Medium Class                                        30736 non-null  bool
#  50  social_class_Upper-Medium Class                                        30736 non-null  bool
#  51  local_size_From 15000 to 99999 people                                  30736 non-null  bool
#  52  local_size_From 2500 to 14999 people                                   30736 non-null  bool
#  53  local_size_Over 100000 people                                          30736 non-null  bool
#  54  age_Adult                                                              30736 non-null  bool
#  55  age_Middle-aged                                                        30736 non-null  bool
#  56  age_Senior                                                             30736 non-null  bool
#  57  age_Teenager                                                           30736 non-null  bool
#  58  age_Young Adult                                                        30736 non-null  bool
# dtypes: bool(57), int64(2)
# memory usage: 2.4 MB

# %%
male_testing_final = male_testing_numeric.drop(
    [
        "starting_point_Construction Site",
        "ending_point_Construction Site",
        "transportation_mode_Bus",
        "start_time_Afternoon",
        "end_time_Afternoon",
        "social_class_High Class",
        "local_size_less than 2500 people",
        "age_Child"
    ],
    axis=1
    )

male_testing_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22424 entries, 14 to 872729
# Data columns (total 59 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   travel_time                                                            22424 non-null  int64
#  1   waiting_time                                                           22424 non-null  int64
#  2   starting_point_Cultural Center or Leisure Area                         22424 non-null  bool
#  3   starting_point_Factory or Workshop                                     22424 non-null  bool
#  4   starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory  22424 non-null  bool
#  5   starting_point_Office                                                  22424 non-null  bool
#  6   starting_point_Other Enclosures                                        22424 non-null  bool
#  7   starting_point_Other Services                                          22424 non-null  bool
#  8   starting_point_Others                                                  22424 non-null  bool
#  9   starting_point_Public Transportation Hub or Station                    22424 non-null  bool
#  10  starting_point_Religious Area                                          22424 non-null  bool
#  11  starting_point_Restaurant, Bar, Cafe                                   22424 non-null  bool
#  12  starting_point_School                                                  22424 non-null  bool
#  13  starting_point_Shop, Market, Store, or Shopping Mall                   22424 non-null  bool
#  14  starting_point_Sports, Gym                                             22424 non-null  bool
#  15  starting_point_Thoroughfare                                            22424 non-null  bool
#  16  starting_point_Your Home                                               22424 non-null  bool
#  17  ending_point_Cultural Center or Leisure Area                           22424 non-null  bool
#  18  ending_point_Factory or Workshop                                       22424 non-null  bool
#  19  ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory    22424 non-null  bool
#  20  ending_point_Office                                                    22424 non-null  bool
#  21  ending_point_Other Enclosures                                          22424 non-null  bool
#  22  ending_point_Other Services                                            22424 non-null  bool
#  23  ending_point_Others                                                    22424 non-null  bool
#  24  ending_point_Public Transportation Hub or Station                      22424 non-null  bool
#  25  ending_point_Religious Area                                            22424 non-null  bool
#  26  ending_point_Restaurant, Bar, Cafe                                     22424 non-null  bool
#  27  ending_point_School                                                    22424 non-null  bool
#  28  ending_point_Shop, Market, Store, or Shopping Mall                     22424 non-null  bool
#  29  ending_point_Sports, Gym                                               22424 non-null  bool
#  30  ending_point_Thoroughfare                                              22424 non-null  bool
#  31  ending_point_Your Home                                                 22424 non-null  bool
#  32  transportation_mode_Others                                             22424 non-null  bool
#  33  transportation_mode_Private                                            22424 non-null  bool
#  34  transportation_mode_Rail                                               22424 non-null  bool
#  35  transportation_mode_Taxi                                               22424 non-null  bool
#  36  transportation_mode_Walking                                            22424 non-null  bool
#  37  transportation_mode_cycles                                             22424 non-null  bool
#  38  start_time_Evening                                                     22424 non-null  bool
#  39  start_time_Midnight                                                    22424 non-null  bool
#  40  start_time_Morning                                                     22424 non-null  bool
#  41  start_time_Night                                                       22424 non-null  bool
#  42  start_time_Noon                                                        22424 non-null  bool
#  43  end_time_Evening                                                       22424 non-null  bool
#  44  end_time_Midnight                                                      22424 non-null  bool
#  45  end_time_Morning                                                       22424 non-null  bool
#  46  end_time_Night                                                         22424 non-null  bool
#  47  end_time_Noon                                                          22424 non-null  bool
#  48  social_class_Low Class                                                 22424 non-null  bool
#  49  social_class_Lower-Medium Class                                        22424 non-null  bool
#  50  social_class_Upper-Medium Class                                        22424 non-null  bool
#  51  local_size_From 15000 to 99999 people                                  22424 non-null  bool
#  52  local_size_From 2500 to 14999 people                                   22424 non-null  bool
#  53  local_size_Over 100000 people                                          22424 non-null  bool
#  54  age_Adult                                                              22424 non-null  bool
#  55  age_Middle-aged                                                        22424 non-null  bool
#  56  age_Senior                                                             22424 non-null  bool
#  57  age_Teenager                                                           22424 non-null  bool
#  58  age_Young Adult                                                        22424 non-null  bool
# dtypes: bool(57), int64(2)
# memory usage: 1.7 MB

# %%
# 将所有布尔列转换为整型
female_testing_final_int = female_testing_final.astype(int)

# 确认转换后的数据类型
print(female_testing_final_int.dtypes)
# Out:
# travel_time                                                              int64
# waiting_time                                                             int64
# starting_point_Cultural Center or Leisure Area                           int64
# starting_point_Factory or Workshop                                       int64
# starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory    int64
# starting_point_Office                                                    int64
# starting_point_Other Enclosures                                          int64
# starting_point_Other Services                                            int64
# starting_point_Others                                                    int64
# starting_point_Public Transportation Hub or Station                      int64
# starting_point_Religious Area                                            int64
# starting_point_Restaurant, Bar, Cafe                                     int64
# starting_point_School                                                    int64
# starting_point_Shop, Market, Store, or Shopping Mall                     int64
# starting_point_Sports, Gym                                               int64
# starting_point_Thoroughfare                                              int64
# starting_point_Your Home                                                 int64
# ending_point_Cultural Center or Leisure Area                             int64
# ending_point_Factory or Workshop                                         int64
# ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory      int64
# ending_point_Office                                                      int64
# ending_point_Other Enclosures                                            int64
# ending_point_Other Services                                              int64
# ending_point_Others                                                      int64
# ending_point_Public Transportation Hub or Station                        int64
# ending_point_Religious Area                                              int64
# ending_point_Restaurant, Bar, Cafe                                       int64
# ending_point_School                                                      int64
# ending_point_Shop, Market, Store, or Shopping Mall                       int64
# ending_point_Sports, Gym                                                 int64
# ending_point_Thoroughfare                                                int64
# ending_point_Your Home                                                   int64
# transportation_mode_Others                                               int64
# transportation_mode_Private                                              int64
# transportation_mode_Rail                                                 int64
# transportation_mode_Taxi                                                 int64
# transportation_mode_Walking                                              int64
# transportation_mode_cycles                                               int64
# start_time_Evening                                                       int64
# start_time_Midnight                                                      int64
# start_time_Morning                                                       int64
# start_time_Night                                                         int64
# start_time_Noon                                                          int64
# end_time_Evening                                                         int64
# end_time_Midnight                                                        int64
# end_time_Morning                                                         int64
# end_time_Night                                                           int64
# end_time_Noon                                                            int64
# social_class_Low Class                                                   int64
# social_class_Lower-Medium Class                                          int64
# social_class_Upper-Medium Class                                          int64
# local_size_From 15000 to 99999 people                                    int64
# local_size_From 2500 to 14999 people                                     int64
# local_size_Over 100000 people                                            int64
# age_Adult                                                                int64
# age_Middle-aged                                                          int64
# age_Senior                                                               int64
# age_Teenager                                                             int64
# age_Young Adult                                                          int64
# dtype: object

# %%
# 将所有布尔列转换为整型
male_testing_final_int = male_testing_final.astype(int)

# 确认转换后的数据类型
print(male_testing_final_int.dtypes)
# Out:
# travel_time                                                              int64
# waiting_time                                                             int64
# starting_point_Cultural Center or Leisure Area                           int64
# starting_point_Factory or Workshop                                       int64
# starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory    int64
# starting_point_Office                                                    int64
# starting_point_Other Enclosures                                          int64
# starting_point_Other Services                                            int64
# starting_point_Others                                                    int64
# starting_point_Public Transportation Hub or Station                      int64
# starting_point_Religious Area                                            int64
# starting_point_Restaurant, Bar, Cafe                                     int64
# starting_point_School                                                    int64
# starting_point_Shop, Market, Store, or Shopping Mall                     int64
# starting_point_Sports, Gym                                               int64
# starting_point_Thoroughfare                                              int64
# starting_point_Your Home                                                 int64
# ending_point_Cultural Center or Leisure Area                             int64
# ending_point_Factory or Workshop                                         int64
# ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory      int64
# ending_point_Office                                                      int64
# ending_point_Other Enclosures                                            int64
# ending_point_Other Services                                              int64
# ending_point_Others                                                      int64
# ending_point_Public Transportation Hub or Station                        int64
# ending_point_Religious Area                                              int64
# ending_point_Restaurant, Bar, Cafe                                       int64
# ending_point_School                                                      int64
# ending_point_Shop, Market, Store, or Shopping Mall                       int64
# ending_point_Sports, Gym                                                 int64
# ending_point_Thoroughfare                                                int64
# ending_point_Your Home                                                   int64
# transportation_mode_Others                                               int64
# transportation_mode_Private                                              int64
# transportation_mode_Rail                                                 int64
# transportation_mode_Taxi                                                 int64
# transportation_mode_Walking                                              int64
# transportation_mode_cycles                                               int64
# start_time_Evening                                                       int64
# start_time_Midnight                                                      int64
# start_time_Morning                                                       int64
# start_time_Night                                                         int64
# start_time_Noon                                                          int64
# end_time_Evening                                                         int64
# end_time_Midnight                                                        int64
# end_time_Morning                                                         int64
# end_time_Night                                                           int64
# end_time_Noon                                                            int64
# social_class_Low Class                                                   int64
# social_class_Lower-Medium Class                                          int64
# social_class_Upper-Medium Class                                          int64
# local_size_From 15000 to 99999 people                                    int64
# local_size_From 2500 to 14999 people                                     int64
# local_size_Over 100000 people                                            int64
# age_Adult                                                                int64
# age_Middle-aged                                                          int64
# age_Senior                                                               int64
# age_Teenager                                                             int64
# age_Young Adult                                                          int64
# dtype: object

# %%
############################ calculating VIF #############################
# This function is adjusted from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: (default 5) the threshould VIF value. If the VIF of a variable is greater than thresh, it should be removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data. add_constant is a function from statsmodels (see the import above)
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        # If there are multiple variabels with VIF>thresh, only one of them is removed. This is because we want to keep as many variables as possible
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
# using VIF on the testing dataset
female_df_predictors_selected_VIF = drop_column_using_vif_(female_testing_final_int)
# Out:
# Dropping: starting_point_Your Home
# Dropping: ending_point_School
# Dropping: start_time_Morning
# Dropping: local_size_Over 100000 people
# Dropping: end_time_Night

# %%
# using VIF on the testing dataset
male_df_predictors_selected_VIF = drop_column_using_vif_(male_testing_final_int)
# Out:
# Dropping: ending_point_Shop, Market, Store, or Shopping Mall
# Dropping: starting_point_Your Home
# Dropping: local_size_Over 100000 people
# Dropping: start_time_Morning
# Dropping: end_time_Night

# %%
############# Checking the correlation between variables ##############
df = male_testing_final_int
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=90)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)

plt.savefig('correlation_male.png', bbox_inches='tight', dpi=300) 
plt.title('Correlation Matrix', fontsize=16)

# %%
############# Checking the correlation between variables ##############
df = female_testing_final_int
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=90)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)

plt.savefig('correlation_female.png', bbox_inches='tight', dpi=300) 
plt.title('female_Correlation Matrix', fontsize=16)

# %%
# Assuming `male_testing_final_int` and `female_testing_final_int` are defined
# Compute correlation matrices
corr_male = male_testing_final_int.corr()
corr_female = female_testing_final_int.corr()

# Compute the difference between the two correlation matrices
corr_diff = corr_male - corr_female

# Plotting the difference matrix
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))

# Use a diverging colormap with white at the center
cmap = plt.cm.bwr

# Set the background of the figure to white
f.patch.set_facecolor('white')

# Plotting the matrix with white in the middle of the color scale
plt.matshow(corr_diff, fignum=f.number, cmap=cmap, vmin=-1, vmax=1)
plt.xticks(range(corr_diff.shape[1]), corr_diff.columns, fontsize=14, rotation=90)
plt.yticks(range(corr_diff.shape[1]), corr_diff.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)

# Save the plot if needed
plt.savefig('correlation_difference_gender.png', bbox_inches='tight', dpi=300, facecolor='white')
plt.show()

# %%
female_X = female_df_predictors_selected_VIF
female_y = female_data_undersampled['travel_purpose']

# %%
male_X = male_df_predictors_selected_VIF
male_y = male_data_undersampled['travel_purpose']

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

# %%
def backward_elimination_multinomial(X, y, batch_size=100, significance_level=0.05):
    features = X.columns.tolist()
    
    while len(features) > 0:
        batch_features = [features[i:i + batch_size] for i in range(0, len(features), batch_size)]
        max_p_value = 0
        feature_to_remove = None
        
        for batch in batch_features:
            X_1 = sm.add_constant(X[batch])
            model = sm.MNLogit(y, X_1).fit(disp=0)  # 使用多类逻辑回归模型
            p_values = model.pvalues.iloc[1:].max(axis=1)  # 获取p值，跳过常数项
            
            if p_values.max() > max_p_value:
                max_p_value = p_values.max()
                feature_to_remove = p_values.idxmax()
        
        if max_p_value > significance_level:
            features.remove(feature_to_remove)
        else:
            break
    
    return features

# %%
def logistic_regression_analysis(X, y, test_size=0.3, random_state=42, batch_size=100, significance_level=0.05):
    """
    执行多元逻辑回归分析，并生成混淆矩阵和分类报告。
    
    参数:
    X (DataFrame): 包含特征的数据集
    y (Series): 目标变量
    test_size (float): 测试集大小（默认 0.3）
    random_state (int): 随机种子（默认 42）
    batch_size (int): 后向筛选的批次大小（默认 100）
    significance_level (float): 后向筛选的显著性水平（默认 0.05）
    
    返回:
    results (dict): 包含训练集和测试集准确性，混淆矩阵和分类报告的字典
    """

    # 拆分数据集为训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # 执行后向筛选
    selected_features = backward_elimination_multinomial(X_train, y_train, batch_size=batch_size, significance_level=significance_level)
    print("Selected features after backward elimination:", selected_features)

    # 使用筛选后的特征集
    X_train_final = X_train[selected_features]
    X_test_final = X_test[selected_features]
    
    # 初始化并训练逻辑回归模型
    model = LogisticRegression(max_iter=1000, multi_class='multinomial', solver='lbfgs')
    model.fit(X_train_final, y_train)

    # 预测
    y_train_pred = model.predict(X_train_final)
    y_test_pred = model.predict(X_test_final)
    
    # 计算准确性
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    # 混淆矩阵
    cm = confusion_matrix(y_test, y_test_pred)
    
    # 打印分类报告
    report = classification_report(y_test, y_test_pred)
    
    # 可视化混淆矩阵
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    # 打印结果
    print("Training Accuracy: {:.4f}".format(train_accuracy))
    print("Test Accuracy: {:.4f}".format(test_accuracy))
    print("Classification Report:\n", report)

# %%
female_results = logistic_regression_analysis(female_X, female_y)
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# Selected features after backward elimination: ['travel_time', 'waiting_time', 'starting_point_Cultural Center or Leisure Area', 'starting_point_Factory or Workshop', "starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'starting_point_Office', 'starting_point_Other Enclosures', 'starting_point_Other Services', 'starting_point_Others', 'starting_point_Public Transportation Hub or Station', 'starting_point_Religious Area', 'starting_point_Restaurant, Bar, Cafe', 'starting_point_School', 'starting_point_Shop, Market, Store, or Shopping Mall', 'starting_point_Sports, Gym', 'starting_point_Thoroughfare', 'ending_point_Cultural Center or Leisure Area', 'ending_point_Factory or Workshop', "ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'ending_point_Office', 'ending_point_Other Enclosures', 'ending_point_Other Services', 'ending_point_Others', 'ending_point_Public Transportation Hub or Station', 'ending_point_Religious Area', 'ending_point_Restaurant, Bar, Cafe', 'ending_point_Shop, Market, Store, or Shopping Mall', 'ending_point_Sports, Gym', 'ending_point_Thoroughfare', 'ending_point_Your Home', 'transportation_mode_Others', 'transportation_mode_Private', 'transportation_mode_Rail', 'transportation_mode_Taxi', 'transportation_mode_Walking', 'transportation_mode_cycles', 'start_time_Evening', 'start_time_Midnight', 'start_time_Night', 'start_time_Noon', 'end_time_Evening', 'end_time_Midnight', 'end_time_Morning', 'end_time_Noon', 'social_class_Low Class', 'social_class_Lower-Medium Class', 'social_class_Upper-Medium Class', 'local_size_From 15000 to 99999 people', 'local_size_From 2500 to 14999 people', 'age_Adult', 'age_Middle-aged', 'age_Senior', 'age_Teenager', 'age_Young Adult']
# Training Accuracy: 0.7969
# Test Accuracy: 0.7985
# Classification Report:
#                                     precision    recall  f1-score   support
#
#          Execution of the program       0.75      0.54      0.63      1154
#                       Go Shopping       0.70      0.91      0.79      1222
#                           Go home       1.00      1.00      1.00      1129
#                       Go to study       0.84      0.86      0.85      1098
#                        Go to work       0.76      0.57      0.65      1165
# Having fun with friends or family       0.76      0.83      0.79      1172
#                    Pick up people       0.76      0.70      0.73      1123
#           To receive medical care       0.83      0.98      0.90      1158
#
#                          accuracy                           0.80      9221
#                         macro avg       0.80      0.80      0.79      9221
#                      weighted avg       0.80      0.80      0.79      9221

# %%
def logistic_regression_analysis(X, y, test_size=0.3, random_state=42, batch_size=100, significance_level=0.05, return_features_only=False, return_feature_names=False):
    """
    执行多元逻辑回归分析，并生成混淆矩阵和分类报告。
    
    参数:
    X (DataFrame): 包含特征的数据集
    y (Series): 目标变量
    test_size (float): 测试集大小（默认 0.3）
    random_state (int): 随机种子（默认 42）
    batch_size (int): 后向筛选的批次大小（默认 100）
    significance_level (float): 后向筛选的显著性水平（默认 0.05）
    return_features_only (bool): 是否只返回筛选出的特征而不进行后续模型训练和评估（默认 False）
    return_feature_names (bool): 是否返回特征名称
    
    返回:
    如果 return_features_only 为 True，返回筛选后的特征列表；
    如果 return_feature_names 为 True，返回包含模型、结果字典和特征名称的元组；
    否则返回包含训练集和测试集准确性，混淆矩阵和分类报告的字典。
    """

    # 拆分数据集为训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # 重置索引
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # 标准化
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    # 多项式特征变换
    poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)

    # 获取特征名称
    feature_names = poly.get_feature_names_out(X.columns)
    X_train_poly_df = pd.DataFrame(X_train_poly, columns=feature_names)
    X_test_poly_df = pd.DataFrame(X_test_poly, columns=feature_names)

    # 执行后向筛选
    selected_features = backward_elimination_multinomial(X_train_poly_df, y_train, batch_size=batch_size, significance_level=significance_level)
    print("Selected features after backward elimination:", selected_features)

    # 如果只返回筛选的特征
    if return_features_only:
        return selected_features

    # 使用筛选后的特征集
    X_train_final = X_train_poly_df[selected_features]
    X_test_final = X_test_poly_df[selected_features]
    
    # 初始化并训练逻辑回归模型
    model = LogisticRegression(max_iter=1000, multi_class='multinomial', solver='lbfgs')
    model.fit(X_train_final, y_train)

    # 预测
    y_train_pred = model.predict(X_train_final)
    y_test_pred = model.predict(X_test_final)
    
    # 计算准确性
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)

    # 混淆矩阵
    conf_matrix = confusion_matrix(y_test, y_test_pred, labels=model.classes_)
    
    # 打印分类报告
    report = classification_report(y_test, y_test_pred)

    # 假设类标签为具体的名称（根据实际数据替换）
    class_names = [
        "Go home", "Go to work", "Go to Study", "Go Shopping", 
        "Having fun with friends or family", "Pick up people", 
        "Execution of the program", "To receive medical care"
    ]

    # 使用类名替换数字标签，并调整图形尺寸
    fig, ax = plt.subplots(figsize=(10, 8))  # 增加图形尺寸
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, ax=ax)
    plt.xticks(rotation=35, ha="right")  # 调整标签旋转角度和对齐方式
    plt.yticks(rotation=0)  # 保持 y 轴标签水平
    plt.title("Confusion Matrix with Class Names")
    plt.show()
    
    # 打印结果
    print("Training Accuracy: {:.4f}".format(train_accuracy))
    print("Test Accuracy: {:.4f}".format(test_accuracy))
    print("Classification Report:\n", report)
    
    # 返回模型和结果字典
    results = {
        "model": model,
        "train_accuracy": train_accuracy,
        "test_accuracy": test_accuracy,
        "confusion_matrix": conf_matrix,
        "classification_report": report
    }
    
    if return_feature_names:
        return results, feature_names

    return results

# %%
female_results = logistic_regression_analysis(female_X, female_y)
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# Selected features after backward elimination: ['travel_time', 'waiting_time', 'starting_point_Cultural Center or Leisure Area', 'starting_point_Factory or Workshop', "starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'starting_point_Office', 'starting_point_Other Enclosures', 'starting_point_Other Services', 'starting_point_Others', 'starting_point_Public Transportation Hub or Station', 'starting_point_Religious Area', 'starting_point_Restaurant, Bar, Cafe', 'starting_point_School', 'starting_point_Shop, Market, Store, or Shopping Mall', 'starting_point_Sports, Gym', 'starting_point_Thoroughfare', 'ending_point_Cultural Center or Leisure Area', 'ending_point_Factory or Workshop', "ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'ending_point_Office', 'ending_point_Other Enclosures', 'ending_point_Other Services', 'ending_point_Others', 'ending_point_Public Transportation Hub or Station', 'ending_point_Religious Area', 'ending_point_Restaurant, Bar, Cafe', 'ending_point_Shop, Market, Store, or Shopping Mall', 'ending_point_Sports, Gym', 'ending_point_Thoroughfare', 'ending_point_Your Home', 'transportation_mode_Others', 'transportation_mode_Private', 'transportation_mode_Rail', 'transportation_mode_Taxi', 'transportation_mode_Walking', 'transportation_mode_cycles', 'start_time_Evening', 'start_time_Midnight', 'start_time_Night', 'start_time_Noon', 'end_time_Evening', 'end_time_Midnight', 'end_time_Morning', 'end_time_Noon', 'social_class_Low Class', 'social_class_Lower-Medium Class', 'social_class_Upper-Medium Class', 'local_size_From 15000 to 99999 people', 'local_size_From 2500 to 14999 people', 'age_Adult', 'age_Middle-aged', 'age_Senior', 'age_Teenager', 'age_Young Adult', 'travel_time waiting_time', 'travel_time starting_point_Cultural Center or Leisure Area', 'travel_time starting_point_Factory or Workshop', "travel_time starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'travel_time starting_point_Office', 'travel_time starting_point_Other Enclosures', 'travel_time starting_point_Other Services', 'travel_time starting_point_Others', 'travel_time starting_point_Public Transportation Hub or Station', 'travel_time starting_point_Religious Area', 'travel_time starting_point_Restaurant, Bar, Cafe', 'travel_time starting_point_School', 'travel_time starting_point_Shop, Market, Store, or Shopping Mall', 'travel_time starting_point_Sports, Gym', 'travel_time starting_point_Thoroughfare', 'travel_time ending_point_Cultural Center or Leisure Area', 'travel_time ending_point_Factory or Workshop', "travel_time ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'travel_time ending_point_Office', 'travel_time ending_point_Other Enclosures', 'travel_time ending_point_Other Services', 'travel_time ending_point_Others', 'travel_time ending_point_Public Transportation Hub or Station', 'travel_time ending_point_Religious Area', 'travel_time ending_point_Restaurant, Bar, Cafe', 'travel_time ending_point_Shop, Market, Store, or Shopping Mall', 'travel_time ending_point_Sports, Gym', 'travel_time ending_point_Thoroughfare', 'travel_time ending_point_Your Home', 'travel_time transportation_mode_Others', 'travel_time transportation_mode_Private', 'travel_time transportation_mode_Rail', 'travel_time transportation_mode_Taxi', 'travel_time transportation_mode_Walking', 'travel_time transportation_mode_cycles', 'travel_time start_time_Evening', 'travel_time start_time_Midnight', 'travel_time start_time_Night', 'travel_time start_time_Noon', 'travel_time end_time_Evening', 'travel_time end_time_Midnight', 'travel_time end_time_Morning', 'travel_time end_time_Noon', 'travel_time social_class_Low Class', 'travel_time social_class_Lower-Medium Class', 'travel_time social_class_Upper-Medium Class', 'travel_time local_size_From 15000 to 99999 people', 'travel_time local_size_From 2500 to 14999 people', 'travel_time age_Adult', 'travel_time age_Middle-aged', 'travel_time  ...
# Training Accuracy: 0.8379
# Test Accuracy: 0.7996
# Classification Report:
#                                     precision    recall  f1-score   support
#
#          Execution of the program       0.73      0.57      0.64      1154
#                       Go Shopping       0.72      0.88      0.79      1222
#                           Go home       1.00      1.00      1.00      1129
#                       Go to study       0.83      0.86      0.85      1098
#                        Go to work       0.73      0.63      0.68      1165
# Having fun with friends or family       0.79      0.80      0.79      1172
#                    Pick up people       0.75      0.71      0.73      1123
#           To receive medical care       0.84      0.94      0.89      1158
#
#                          accuracy                           0.80      9221
#                         macro avg       0.80      0.80      0.80      9221
#                      weighted avg       0.80      0.80      0.80      9221

# %%
male_results = logistic_regression_analysis(male_X, male_y)
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3025: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /opt/conda/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:3026: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# Selected features after backward elimination: ['travel_time', 'waiting_time', 'starting_point_Cultural Center or Leisure Area', 'starting_point_Factory or Workshop', "starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'starting_point_Office', 'starting_point_Other Enclosures', 'starting_point_Other Services', 'starting_point_Others', 'starting_point_Public Transportation Hub or Station', 'starting_point_Religious Area', 'starting_point_Restaurant, Bar, Cafe', 'starting_point_School', 'starting_point_Shop, Market, Store, or Shopping Mall', 'starting_point_Sports, Gym', 'starting_point_Thoroughfare', 'ending_point_Cultural Center or Leisure Area', 'ending_point_Factory or Workshop', "ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'ending_point_Office', 'ending_point_Other Enclosures', 'ending_point_Other Services', 'ending_point_Others', 'ending_point_Public Transportation Hub or Station', 'ending_point_Religious Area', 'ending_point_Restaurant, Bar, Cafe', 'ending_point_School', 'ending_point_Sports, Gym', 'ending_point_Thoroughfare', 'ending_point_Your Home', 'transportation_mode_Others', 'transportation_mode_Private', 'transportation_mode_Rail', 'transportation_mode_Taxi', 'transportation_mode_Walking', 'transportation_mode_cycles', 'start_time_Evening', 'start_time_Midnight', 'start_time_Night', 'start_time_Noon', 'end_time_Evening', 'end_time_Midnight', 'end_time_Morning', 'end_time_Noon', 'social_class_Low Class', 'social_class_Lower-Medium Class', 'social_class_Upper-Medium Class', 'local_size_From 15000 to 99999 people', 'local_size_From 2500 to 14999 people', 'age_Adult', 'age_Middle-aged', 'age_Senior', 'age_Teenager', 'age_Young Adult', 'travel_time waiting_time', 'travel_time starting_point_Cultural Center or Leisure Area', 'travel_time starting_point_Factory or Workshop', "travel_time starting_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'travel_time starting_point_Office', 'travel_time starting_point_Other Enclosures', 'travel_time starting_point_Other Services', 'travel_time starting_point_Others', 'travel_time starting_point_Public Transportation Hub or Station', 'travel_time starting_point_Religious Area', 'travel_time starting_point_Restaurant, Bar, Cafe', 'travel_time starting_point_School', 'travel_time starting_point_Shop, Market, Store, or Shopping Mall', 'travel_time starting_point_Sports, Gym', 'travel_time starting_point_Thoroughfare', 'travel_time ending_point_Cultural Center or Leisure Area', 'travel_time ending_point_Factory or Workshop', "travel_time ending_point_Hospital, Clinic, Doctor's Office, Clinical Laboratory", 'travel_time ending_point_Office', 'travel_time ending_point_Other Enclosures', 'travel_time ending_point_Other Services', 'travel_time ending_point_Others', 'travel_time ending_point_Public Transportation Hub or Station', 'travel_time ending_point_Religious Area', 'travel_time ending_point_Restaurant, Bar, Cafe', 'travel_time ending_point_School', 'travel_time ending_point_Sports, Gym', 'travel_time ending_point_Thoroughfare', 'travel_time ending_point_Your Home', 'travel_time transportation_mode_Others', 'travel_time transportation_mode_Private', 'travel_time transportation_mode_Rail', 'travel_time transportation_mode_Taxi', 'travel_time transportation_mode_Walking', 'travel_time transportation_mode_cycles', 'travel_time start_time_Evening', 'travel_time start_time_Midnight', 'travel_time start_time_Night', 'travel_time start_time_Noon', 'travel_time end_time_Evening', 'travel_time end_time_Midnight', 'travel_time end_time_Morning', 'travel_time end_time_Noon', 'travel_time social_class_Low Class', 'travel_time social_class_Lower-Medium Class', 'travel_time social_class_Upper-Medium Class', 'travel_time local_size_From 15000 to 99999 people', 'travel_time local_size_From 2500 to 14999 people', 'travel_time age_Adult', 'travel_time age_Middle-aged', 'travel_time age_Senior', 'travel_time age_Teenager', 'travel_time age_Youn ...
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Accuracy: 0.8404
# Test Accuracy: 0.7802
# Classification Report:
#                                     precision    recall  f1-score   support
#
#          Execution of the program       0.74      0.56      0.64       804
#                       Go Shopping       0.66      0.83      0.74       864
#                           Go home       1.00      0.99      1.00       850
#                       Go to study       0.85      0.91      0.88       838
#                        Go to work       0.68      0.66      0.67       862
# Having fun with friends or family       0.76      0.78      0.77       874
#                    Pick up people       0.70      0.55      0.62       817
#           To receive medical care       0.84      0.94      0.89       819
#
#                          accuracy                           0.78      6728
#                         macro avg       0.78      0.78      0.77      6728
#                      weighted avg       0.78      0.78      0.78      6728
